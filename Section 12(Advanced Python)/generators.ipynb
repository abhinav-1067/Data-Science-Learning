# %%
def my_generator():
    yield 1
    yield 2
    yield 3
    
    
gen = my_generator()
print(next(gen))
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[4], line 11
#       9 print(next(gen))
#      10 print(next(gen))
# ---> 11 print(next(gen))
#
# StopIteration:

# %%
# Practical Example: reading large files

def red_file_lines(file_path):
    with open(file_path,'r') as file:
        for line in file:
            yield line
            
fil = red_file_lines("SSX.txt")
print(next(fil))
print(next(fil))
print(next(fil))
# Out:
# A strong, effective paragraph typically consists of 5–8 sentences,
#
# focusing on a single central idea or topic sentence that is supported by details,
#
# examples, or evidence.
