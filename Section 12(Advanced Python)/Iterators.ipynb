# %%
# Iterators are advanced python concepts that allows for efficient looping and memory management. Iterators provide a way to access the elements of a collection sequentially without exposing the underlying structure.

# %%
my_list = [1,2,3,4,5,6]

iterator = iter(my_list)
print(next(iterator))
print(type(iterator))
# Out:
# 1
# <class 'list_iterator'>

# %%
next(iterator)

# after iterating through all elements it show error of StopIteration
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 next(iterator)
#       3 # after iterating through all elements it show error of StopIteration
#
# StopIteration:

# %%
iterator = iter(my_list)

# %%
# For this error
try:
    print(next(iterator))
except StopIteration:
    print("There is no elements for Iteration")
# Out:
# There is no elements for Iteration
