# %%
## Inheritance is an fundamental concept in object-oriented programming (OOP) that allows a class to inherit attributes and methods from another class.

# %%
#Inheritance
#parent class
class Car():
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype
    def drive(self):
        print(f"This person will drive {self.enginetype}")

# %%
car1 = Car(4,4,"EV")
car1.drive()
# Out:
# This person will drive EV

# %%
# Multiple Inheritance

# Base class 1
class Animal:
    def __init__(self,name):
        self.name = name
    def speak(self):
        print("This argument should implement")
# Base class 2

class Pet:
    def __init__(self,owner):
        self.owner = owner

# now inherited class
class cat(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)
    def speak(self):
        return f"{self.name} says meow!"

cat1 = cat("Jelly","Abhinav")
print(cat1.speak())
# Out:
# Jelly says meow!
