# %%
## A function to read the file and count the frequency of each words

def count_frequency(file_path):
    word_count={}
    with open(file_path,'r') as file:
        for line in file:
            words=line.split()
            for word in words:
                word = word.lower().strip("!@()*&^%''")
                word_count[word] = word_count.get(word,0)+1
    return word_count
filepath = 'sample.txt'
word_frequency = count_frequency(filepath)
print(word_frequency)
# Out:
# {'hello': 1, 'world': 1, 'im': 1, 'abhinav': 3, 'yadav.': 1, 'my': 1, 'name': 1, 'is': 1, 'yadav': 1, 'i': 1, 'live': 1, 'in': 2, 'khargone': 1, 'residance': 1}
