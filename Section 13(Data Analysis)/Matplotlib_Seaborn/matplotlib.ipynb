# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------------- ---------------------- 3.7/8.2 MB 19.8 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 9.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.2 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 7.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 2.1 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,4,9,15,25]

plt.plot(x,y)
plt.xlabel('x-aixs')
plt.ylabel('y-aixs')
plt.title('Basic Graph Plotting')
plt.show()

# %%
# Creating an custom line,

x = [1,2,3,4,5]
y = [1,4,9,15,25]

plt.plot(x,y, color='red', linestyle='--',marker='o')
plt.grid(True)
plt.show()

# %%
# Bar Plot

catergories = ['A','B','C','D','E','F']
values = [1,6,3,4,5,7]

plt.bar(catergories,values,color='blue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot')
plt.show()

# %%
# scatter plot

x = [1,2,3,4,5]
y = [2,4,7,6,3]

plt.scatter(x,y,color='black',marker='x')
plt.show()

# %%
# Pie Chart
labels = ['TMKB','BSDK','BKL','TMB']
sizes = [30,20,28,22]
colors = ['gold','lightskyblue','yellowgreen','lightcoral']

plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('OG Galis')
plt.show()

# %%
# Pie Chart
labels = ['TMKB','BSDK','BKL','TMB']
sizes = [30,20,28,22]
colors = ['gold','lightskyblue','yellowgreen','lightcoral']
explode = [0.2,0,0,0]

plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('OG Galis')
plt.show()

# %%
# bar graph plotting with real data
import pandas as pd
data = pd.read_csv('sales_data.csv')
data
# Out:
#     Order_ID        Date Region     Product  Quantity  Price  Revenue
# 0       1001  2024-01-01  North       Phone       1.0  15000    15000
# 1       1002  2024-01-02  South       Shirt       2.0    500     1000
# 2       1003  2024-01-03   East        Rice       3.0   1200     3600
# 3       1004  2024-01-04   West      Laptop       1.0  50000    50000
# 4       1005  2024-01-05  North       Jeans       2.0   1200     2400
# 5       1006  2024-01-06  South         Oil       1.0    800      800
# 6       1007         NaN   East  Headphones       2.0   2000     4000
# 7       1008  2024-01-08   West     T-Shirt       NaN    600     1800
# 8       1009  2024-01-09  North        Rice       1.0   1200     1200
# 9       1010  2024-01-10  South       Phone       1.0  14000    14000
# 10      1011  2024-01-11    NaN       Shirt       2.0    700     1400
# 11      1012  2024-01-12   West      Laptop       1.0  55000    55000
# ...

# %%
# plotting a bar graph of product with respect to its revenue

total_revenue = data.groupby('Product')['Revenue'].sum()
total_revenue
# Out:
# Product
# Headphones      6500
# Jeans           5000
# Laptop        105000
# Oil             2600
# Phone          29000
# Rice            4800
# Shirt           2400
# T-Shirt         1800
# Name: Revenue, dtype: int64

# %%
total_revenue.plot(kind='bar',color='blue')
# Out:
# <Axes: xlabel='Product'>

# %%
sales_data = data.groupby('Date')['Revenue'].sum().reset_index()
plt.plot(sales_data['Date'],sales_data['Revenue'],color='pink')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Advanced Matlplotlib

# %%
import pandas as pd

# %%
# plotting scatter graph with diff colors
iris = pd.read_csv('iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 43    44            5.0           3.5            1.6           0.6
# 57    58            4.9           2.4            3.3           1.0
# 123  124            6.3           2.7            4.9           1.8
# 30    31            4.8           3.1            1.6           0.2
# 42    43            4.4           3.2            1.3           0.2
#
#              Species
# 43       Iris-setosa
# 57   Iris-versicolor
# 123   Iris-virginica
# 30       Iris-setosa
# 42       Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('SepalLengthCm')
plt.ylable('PetalLengthCm')
iris['Species'] = iris.replace({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})
plt.show()
